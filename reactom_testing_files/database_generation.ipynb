# %%
class ReactomePathway:
    def __init__(self, reactome_sID):
        self.is_Root= False
        self.is_Leaf= False
        self.name= ''
        self.reactome_sID= reactome_sID
        self.children= []
        self.parents= []
        self.level = -1
        self.root_id = ''
    def asdict(self):
        """ return the ReactomePathway  as dictionary 
        """
        return {'reactome_sID': self.reactome_sID, 'children': self.children, 'parents': self.parents, 'is_leaf': self.is_Leaf, 'is_root': self.is_Root, 'level': self.level, 'root_id': self.root_id}        
    def assert_leaf_root_state(self):
        if len(self.children) == 0:
            self.is_Leaf= True
        if len(self.parents) == 0:
            self.is_Root = True

# %%
class PathwayHierarchy(dict):
    def __init__(self, *arg, **kw):
       super(PathwayHierarchy, self).__init__(*arg, **kw)
    def add_hierarchy_levels(self):
        for k,v in self.items():
            level = 0
            not_at_root = True
            next_elem = k
            partent_name = ''
            while not_at_root:
                if len(self[next_elem].parents) < 1:
                    not_at_root = False
                    partent_name = next_elem
                    break
                else:
                    level += 1
                    next_elem = self[next_elem].parents[0] # [0] is temp fix disregards more than one parent
            v.level = level
            v.root_name = next_elem


    def hierarchyInfo(self):
        entries = len(self.keys()) 
        leafs = len([v for k,v in self.items() if v.is_Leaf])
        roots = len([v for k,v in self.items() if v.is_Root])
        return {'size': entries, 'leafs': leafs, 'roots': roots}
    def getLevel(self, key):
        print('test')

# %%
pathways = PathwayHierarchy()

organism = "MMU"

with open('ReactomePathwaysRelation.txt') as fh:
    for line in fh:
        line_list = line.strip().split('\t')
        left_entry = line_list[0]
        right_entry = line_list[1]
        if(organism in left_entry):
            if left_entry not in pathways.keys():
                pathways[left_entry] = ReactomePathway(left_entry)
                pathways[left_entry].children.append(right_entry)
            else:
                pathways[left_entry].children.append(right_entry)
            if right_entry not in pathways.keys():
                pathways[right_entry] = ReactomePathway(right_entry)
                pathways[right_entry].parents.append(left_entry)
            else:
                pathways[right_entry].parents.append(left_entry)

for k,v in pathways.items():
    v.assert_leaf_root_state()

pathways.add_hierarchy_levels()

# %%
uniprot_2_reactome = {}

with open('UniProt2Reactome_PE_Pathway.txt') as fh:
    for line in fh:
        line_split = line.strip().split('\t')
        uniprot_ID = line_split[0]
        reactome_entity_ID = line_split[1]
        entity_name = line_split[2]
        reactome_pathway_ID = line_split[3]
        reactome_pathway_Name = line_split[5]
        organism = line_split[7].replace(' ', '_')
        if organism not in uniprot_2_reactome:
            uniprot_2_reactome[organism] = {}
        if uniprot_ID in uniprot_2_reactome[organism]:
            if reactome_entity_ID in uniprot_2_reactome[organism][uniprot_ID]:
                uniprot_2_reactome[organism][uniprot_ID][reactome_entity_ID]['pathways'].append((reactome_pathway_ID, reactome_pathway_Name))
            else:
                uniprot_2_reactome[organism][uniprot_ID][reactome_entity_ID] = {'reactome_id':reactome_entity_ID, 'name': entity_name, 'pathways': [(reactome_pathway_ID, reactome_pathway_Name)]}
        else:
            uniprot_2_reactome[organism][uniprot_ID] = {}
            uniprot_2_reactome[organism][uniprot_ID][reactome_entity_ID] = {'reactome_id':reactome_entity_ID, 'name': entity_name, 'pathways': [(reactome_pathway_ID, reactome_pathway_Name)]}

# %%
uniprot_2_reactome.keys()
# Out:
# dict_keys(['Drosophila_melanogaster', 'Rattus_norvegicus', 'Danio_rerio', 'Caenorhabditis_elegans', 'Canis_familiaris', 'Mus_musculus', 'Homo_sapiens', 'Sus_scrofa', 'Bos_taurus', 'Gallus_gallus', 'Plasmodium_falciparum', 'Xenopus_tropicalis', 'Schizosaccharomyces_pombe', 'Dictyostelium_discoideum', 'Saccharomyces_cerevisiae', 'Mycobacterium_tuberculosis'])

# %%
import pickle

# %%
for key in uniprot_2_reactome.keys():
    with open('{}_uniprot2reactome.pickle'.format(key), 'wb') as handle:
        pickle.dump(uniprot_2_reactome[key], handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
uniprot_2_reactome["Mus_musculus"]
# Out:
# {'A0A075B5J3': {'R-MMU-198188': {'reactome_id': 'R-MMU-198188',
#    'name': 'Trbc1 [plasma membrane]',
#    'pathways': [('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202424', 'Downstream TCR signaling'),
#     ('R-MMU-202427', 'Phosphorylation of CD3 and TCR zeta chains'),
#     ('R-MMU-202430', 'Translocation of ZAP-70 to Immunological synapse'),
#     ('R-MMU-202433', 'Generation of second messenger molecules'),
#     ('R-MMU-389948', 'PD-1 signaling')]}},
#  'A0A075B5J4': {'R-MMU-198188-2': {'reactome_id': 'R-MMU-198188-2',
#    'name': 'Trbc2 [plasma membrane]',
#    'pathways': [('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202424', 'Downstream TCR signaling'),
#     ('R-MMU-202427', 'Phosphorylation of CD3 and TCR zeta chains'),
#     ('R-MMU-202430', 'Translocation of ZAP-70 to Immunological synapse'),
#     ('R-MMU-202433', 'Generation of second messenger molecules'),
#     ('R-MMU-389948', 'PD-1 signaling')]}},
#  'A0A075B5J9': {'R-MMU-983573': {'reactome_id': 'R-MMU-983573',
#    'name': 'Igkv17-127 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038775': {'reactome_id': 'R-MMU-2038775',
#    'name': 'Igkv17-127 [plasma membrane]',
#    'pathways': [('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5K2': {'R-MMU-983608': {'reactome_id': 'R-MMU-983608',
#    'name': 'Igkv9-124 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-197018': {'reactome_id': 'R-MMU-197018',
#    'name': 'Igkv9-124 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038847': {'reactome_id': 'R-MMU-2038847',
#    'name': 'Igkv9-124 [plasma membrane]',
#    'pathways': [('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]},
#   'R-MMU-2038765': {'reactome_id': 'R-MMU-2038765',
#    'name': 'Igkv9-124 [plasma membrane]',
#    'pathways': [('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5K3': {'R-MMU-983573-2': {'reactome_id': 'R-MMU-983573-2',
#    'name': 'Igkv17-121 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038775-2': {'reactome_id': 'R-MMU-2038775-2',
#    'name': 'Igkv17-121 [plasma membrane]',
#    'pathways': [('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5L0': {'R-MMU-983608-2': {'reactome_id': 'R-MMU-983608-2',
#    'name': 'Igkv10-95 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-197018-2': {'reactome_id': 'R-MMU-197018-2',
#    'name': 'Igkv10-95 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038847-2': {'reactome_id': 'R-MMU-2038847-2',
#    'name': 'Igkv10-95 [plasma membrane]',
#    'pathways': [('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]},
#   'R-MMU-2038765-2': {'reactome_id': 'R-MMU-2038765-2',
#    'name': 'Igkv10-95 [plasma membrane]',
#    'pathways': [('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5L1': {'R-MMU-983608-3': {'reactome_id': 'R-MMU-983608-3',
#    'name': 'Igkv10-94 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-197018-3': {'reactome_id': 'R-MMU-197018-3',
#    'name': 'Igkv10-94 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038847-3': {'reactome_id': 'R-MMU-2038847-3',
#    'name': 'Igkv10-94 [plasma membrane]',
#    'pathways': [('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]},
#   'R-MMU-2038765-3': {'reactome_id': 'R-MMU-2038765-3',
#    'name': 'Igkv10-94 [plasma membrane]',
#    'pathways': [('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5M9': {'R-MMU-983596': {'reactome_id': 'R-MMU-983596',
#    'name': 'Igkv18-36 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038830': {'reactome_id': 'R-MMU-2038830',
#    'name': 'Igkv18-36 [plasma membrane]',
#    'pathways': [('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5N0': {'R-MMU-983584': {'reactome_id': 'R-MMU-983584',
#    'name': 'Igkv1-35 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-8948186': {'reactome_id': 'R-MMU-8948186',
#    'name': 'Igkv1-35 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038814': {'reactome_id': 'R-MMU-2038814',
#    'name': 'Igkv1-35 [plasma membrane]',
#    'pathways': [('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]},
#   'R-MMU-8948192': {'reactome_id': 'R-MMU-8948192',
#    'name': 'Igkv1-35 [plasma membrane]',
#    'pathways': [('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5P7': {'R-MMU-983622': {'reactome_id': 'R-MMU-983622',
#    'name': 'Ighv5-2 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038837': {'reactome_id': 'R-MMU-2038837',
#    'name': 'Ighv5-2 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5P9': {'R-MMU-983622-2': {'reactome_id': 'R-MMU-983622-2',
#    'name': 'Ighv5-4 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038837-2': {'reactome_id': 'R-MMU-2038837-2',
#    'name': 'Ighv5-4 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5Q0': {'R-MMU-983622-3': {'reactome_id': 'R-MMU-983622-3',
#    'name': 'Ighv5-6 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038837-3': {'reactome_id': 'R-MMU-2038837-3',
#    'name': 'Ighv5-6 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5Q2': {'R-MMU-983622-4': {'reactome_id': 'R-MMU-983622-4',
#    'name': 'Ighv5-9 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038837-4': {'reactome_id': 'R-MMU-2038837-4',
#    'name': 'Ighv5-9 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5Q4': {'R-MMU-983622-5': {'reactome_id': 'R-MMU-983622-5',
#    'name': 'Ighv5-12 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-197044': {'reactome_id': 'R-MMU-197044',
#    'name': 'Ighv5-12 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038837-5': {'reactome_id': 'R-MMU-2038837-5',
#    'name': 'Ighv5-12 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]},
#   'R-MMU-2038786': {'reactome_id': 'R-MMU-2038786',
#    'name': 'Ighv5-12 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5Q6': {'R-MMU-983622-6': {'reactome_id': 'R-MMU-983622-6',
#    'name': 'Ighv5-9-1 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038837-6': {'reactome_id': 'R-MMU-2038837-6',
#    'name': 'Ighv5-9-1 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5Q9': {'R-MMU-983550': {'reactome_id': 'R-MMU-983550',
#    'name': 'Ighv5-15 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038859': {'reactome_id': 'R-MMU-2038859',
#    'name': 'Ighv5-15 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5R0': {'R-MMU-983622-7': {'reactome_id': 'R-MMU-983622-7',
#    'name': 'Ighv5-16 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038837-7': {'reactome_id': 'R-MMU-2038837-7',
#    'name': 'Ighv5-16 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5R1': {'R-MMU-983614': {'reactome_id': 'R-MMU-983614',
#    'name': 'Ighv5-17 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038827': {'reactome_id': 'R-MMU-2038827',
#    'name': 'Ighv5-17 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5R4': {'R-MMU-983534': {'reactome_id': 'R-MMU-983534',
#    'name': 'Ighv14-1 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038787': {'reactome_id': 'R-MMU-2038787',
#    'name': 'Ighv14-1 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5R5': {'R-MMU-983571': {'reactome_id': 'R-MMU-983571',
#    'name': 'Ighv4-1 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038843': {'reactome_id': 'R-MMU-2038843',
#    'name': 'Ighv4-1 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5R6': {'R-MMU-983622-8': {'reactome_id': 'R-MMU-983622-8',
#    'name': 'Ighv11-1 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038837-8': {'reactome_id': 'R-MMU-2038837-8',
#    'name': 'Ighv11-1 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5R7': {'R-MMU-983534-2': {'reactome_id': 'R-MMU-983534-2',
#    'name': 'Ighv14-2 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038787-2': {'reactome_id': 'R-MMU-2038787-2',
#    'name': 'Ighv14-2 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5R8': {'R-MMU-983622-9': {'reactome_id': 'R-MMU-983622-9',
#    'name': 'Ighv11-2 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038837-9': {'reactome_id': 'R-MMU-2038837-9',
#    'name': 'Ighv11-2 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5R9': {'R-MMU-983534-3': {'reactome_id': 'R-MMU-983534-3',
#    'name': 'Ighv14-3 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038787-3': {'reactome_id': 'R-MMU-2038787-3',
#    'name': 'Ighv14-3 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5S3': {'R-MMU-983534-4': {'reactome_id': 'R-MMU-983534-4',
#    'name': 'Ighv14-4 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038787-4': {'reactome_id': 'R-MMU-2038787-4',
#    'name': 'Ighv14-4 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5S4': {'R-MMU-983653': {'reactome_id': 'R-MMU-983653',
#    'name': 'Ighv3-3 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-1591202': {'reactome_id': 'R-MMU-1591202',
#    'name': 'Ighv3-3 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038772': {'reactome_id': 'R-MMU-2038772',
#    'name': 'Ighv3-3 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]},
#   'R-MMU-2038794': {'reactome_id': 'R-MMU-2038794',
#    'name': 'Ighv3-3 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5S6': {'R-MMU-983653-2': {'reactome_id': 'R-MMU-983653-2',
#    'name': 'Ighv3-1 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-1591202-2': {'reactome_id': 'R-MMU-1591202-2',
#    'name': 'Ighv3-1 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038772-2': {'reactome_id': 'R-MMU-2038772-2',
#    'name': 'Ighv3-1 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]},
#   'R-MMU-2038794-2': {'reactome_id': 'R-MMU-2038794-2',
#    'name': 'Ighv3-1 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'A0A075B5T0': {'R-MMU-983653-3': {'reactome_id': 'R-MMU-983653-3',
#    'name': 'Ighv3-8 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-1591202-3': {'reactome_id': 'R-MMU-1591202-3',
#    'name': 'Ighv3-8 [extracellular region]',
#    'pathways': [('R-MMU-166663', 'Initial triggering of complement'),
#     ('R-MMU-173623', 'Classical antibody-mediated complement activation'),
#     ('R-MMU-198933',
#      'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-2029481', 'FCGR activation'),
#     ('R-MMU-2029482',
#      'Regulation of actin dynamics for phagocytic cup formation'),
#     ('R-MMU-2029485', 'Role of phospholipids in phagocytosis'),
#     ('R-MMU-2168880', 'Scavenging of heme from plasma'),
#     ('R-MMU-2454202', 'Fc epsilon receptor (FCERI) signaling'),
#     ('R-MMU-2730905', 'Role of LAT2/NTAL/LAB on calcium mobilization'),
#     ('R-MMU-2871796', 'FCERI mediated MAPK activation'),
#     ('R-MMU-2871809', 'FCERI mediated Ca+2 mobilization'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-977606', 'Regulation of Complement cascade')]},
#   'R-MMU-2038772-3': {'reactome_id': 'R-MMU-2038772-3',
#    'name': 'Ighv3-8 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]},
#   'R-MMU-2038794-3': {'reactome_id': 'R-MMU-2038794-3',
#    'name': 'Ighv3-8 [plasma membrane]',
#    'pathways': [('R-MMU-202733',
#      'Cell surface interactions at the vascular wall'),
#     ('R-MMU-5690714', 'CD22 mediated BCR regulation'),
#     ('R-MMU-983695',
# ...
#    'name': 'Calumenin [endoplasmic reticulum lumen]',
#    'pathways': [('R-MMU-381426',
#      'Regulation of Insulin-like Growth Factor (IGF) transport and uptake by Insulin-like Growth Factor Binding Proteins (IGFBPs)'),
#     ('R-MMU-8957275', 'Post-translational protein phosphorylation')]},
#   'R-MMU-8956931': {'reactome_id': 'R-MMU-8956931',
#    'name': 'phospho-Calu [endoplasmic reticulum lumen]',
#    'pathways': [('R-MMU-381426',
#      'Regulation of Insulin-like Growth Factor (IGF) transport and uptake by Insulin-like Growth Factor Binding Proteins (IGFBPs)'),
#     ('R-MMU-8957275', 'Post-translational protein phosphorylation')]}},
#  'O35892': {'R-MMU-1031705': {'reactome_id': 'R-MMU-1031705',
#    'name': 'Sp100 [nucleoplasm]',
#    'pathways': [('R-MMU-3108214',
#      'SUMOylation of DNA damage response and repair proteins')]},
#   'R-MMU-3000382': {'reactome_id': 'R-MMU-3000382',
#    'name': 'Sp100 [nucleoplasm]',
#    'pathways': [('R-MMU-3108214',
#      'SUMOylation of DNA damage response and repair proteins')]},
#   'R-MMU-3000454': {'reactome_id': 'R-MMU-3000454',
#    'name': 'Sp100 [nucleoplasm]',
#    'pathways': [('R-MMU-3108214',
#      'SUMOylation of DNA damage response and repair proteins')]}},
#  'O35900': {'R-MMU-429849': {'reactome_id': 'R-MMU-429849',
#    'name': 'Lsm2 [cytosol]',
#    'pathways': [('R-MMU-430039', "mRNA decay by 5' to 3' exoribonuclease")]},
#   'R-MMU-71894': {'reactome_id': 'R-MMU-71894',
#    'name': 'Lsm2 [nucleoplasm]',
#    'pathways': [('R-MMU-72163', 'mRNA Splicing - Major Pathway'),
#     ('R-MMU-72165', 'mRNA Splicing - Minor Pathway')]}},
#  'O35902': {'R-MMU-201590': {'reactome_id': 'R-MMU-201590',
#    'name': 'Dsg3 [plasma membrane]',
#    'pathways': [('R-MMU-351906',
#      'Apoptotic cleavage of cell adhesion  proteins'),
#     ('R-MMU-6805567', 'Keratinization'),
#     ('R-MMU-6809371', 'Formation of the cornified envelope')]},
#   'R-MMU-202803': {'reactome_id': 'R-MMU-202803',
#    'name': 'Dsg3 [plasma membrane]',
#    'pathways': [('R-MMU-351906',
#      'Apoptotic cleavage of cell adhesion  proteins')]},
#   'R-MMU-202797': {'reactome_id': 'R-MMU-202797',
#    'name': 'Dsg3 [cytosol]',
#    'pathways': [('R-MMU-351906',
#      'Apoptotic cleavage of cell adhesion  proteins')]},
#   'R-MMU-8847723': {'reactome_id': 'R-MMU-8847723',
#    'name': 'Dsg3 [cornified envelope]',
#    'pathways': [('R-MMU-6809371', 'Formation of the cornified envelope')]}},
#  'O35903': {'R-MMU-373096': {'reactome_id': 'R-MMU-373096',
#    'name': 'Ccl25 [extracellular region]',
#    'pathways': [('R-MMU-380108', 'Chemokine receptors bind chemokines'),
#     ('R-MMU-418594', 'G alpha (i) signalling events')]}},
#  'O35904': {'R-MMU-392274': {'reactome_id': 'R-MMU-392274',
#    'name': 'Pik3cd [plasma membrane]',
#    'pathways': [('R-MMU-1257604', 'PIP3 activates AKT signaling'),
#     ('R-MMU-512988', 'Interleukin-3, Interleukin-5 and GM-CSF signaling'),
#     ('R-MMU-6811558', 'PI5P, PP2A and IER3 Regulate PI3K/AKT Signaling'),
#     ('R-MMU-8853659', 'RET signaling'),
#     ('R-MMU-912526', 'Interleukin receptor SHC signaling'),
#     ('R-MMU-912631', 'Regulation of signaling by CBL'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]},
#   'R-MMU-1806204': {'reactome_id': 'R-MMU-1806204',
#    'name': 'Pik3cd [cytosol]',
#    'pathways': [('R-MMU-1660499', 'Synthesis of PIPs at the plasma membrane'),
#     ('R-MMU-9027276',
#      'Erythropoietin activates Phosphoinositide-3-kinase (PI3K)'),
#     ('R-MMU-983695',
#      'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers')]}},
#  'O35930': {'R-MMU-55861': {'reactome_id': 'R-MMU-55861',
#    'name': 'Gp1ba [plasma membrane]',
#    'pathways': [('R-MMU-140837', 'Intrinsic Pathway of Fibrin Clot Formation'),
#     ('R-MMU-430116', 'GP1b-IX-V activation signalling'),
#     ('R-MMU-75892', 'Platelet Adhesion to exposed collagen'),
#     ('R-MMU-76009', 'Platelet Aggregation (Plug Formation)')]}},
#  'O35936': {'R-MMU-2142725': {'reactome_id': 'R-MMU-2142725',
#    'name': 'Alox8 [cytosol]',
#    'pathways': [('R-MMU-2142770',
#      'Synthesis of 15-eicosatetraenoic acid derivatives')]}},
#  'O35942': {'R-MMU-177329': {'reactome_id': 'R-MMU-177329',
#    'name': 'Nek2 [cytosol]',
#    'pathways': [('R-MMU-179409', 'APC-Cdc20 mediated degradation of Nek2A'),
#     ('R-MMU-2565942', 'Regulation of PLK1 Activity at G2/M Transition'),
#     ('R-MMU-380259', 'Loss of Nlp from mitotic centrosomes'),
#     ('R-MMU-380270',
#      'Recruitment of mitotic centrosome proteins and complexes'),
#     ('R-MMU-380284',
#      'Loss of proteins required for interphase microtubule organization from the centrosome'),
#     ('R-MMU-380320', 'Recruitment of NuMA to mitotic centrosomes'),
#     ('R-MMU-5620912', 'Anchoring of the basal body to the plasma membrane'),
#     ('R-MMU-8854518', 'AURKA Activation by TPX2')]}},
#  'O35943': {'R-MMU-8986117': {'reactome_id': 'R-MMU-8986117',
#    'name': 'Fxn [mitochondrial matrix]',
#    'pathways': [('R-MMU-1268020', 'Mitochondrial protein import')]},
#   'R-MMU-1362390': {'reactome_id': 'R-MMU-1362390',
#    'name': 'Fxn [mitochondrial matrix]',
#    'pathways': [('R-MMU-1362409',
#      'Mitochondrial iron-sulfur cluster biogenesis')]}},
#  'O35949': {'R-MMU-548785': {'reactome_id': 'R-MMU-548785',
#    'name': 'Elovl3 [endoplasmic reticulum membrane]',
#    'pathways': [('R-MMU-2046105', 'Linoleic acid (LA) metabolism'),
#     ('R-MMU-2046106', 'alpha-linolenic acid (ALA) metabolism'),
#     ('R-MMU-75876', 'Synthesis of very long-chain fatty acyl-CoAs')]}},
#  'O35954': {'R-MMU-5216006': {'reactome_id': 'R-MMU-5216006',
#    'name': 'Pitpnm1 [cytosol]',
#    'pathways': [('R-MMU-1483226', 'Synthesis of PI')]}},
#  'O35955': {'R-MMU-1236811': {'reactome_id': 'R-MMU-1236811',
#    'name': 'Proteasome subunit beta type-10 [cytosol]',
#    'pathways': [('R-MMU-1169091', 'Activation of NF-kappaB in B cells'),
#     ('R-MMU-1234176',
#      'Oxygen-dependent proline hydroxylation of Hypoxia-inducible Factor Alpha'),
#     ('R-MMU-1236978',
#      'Cross-presentation of soluble exogenous antigens (endosomes)'),
#     ('R-MMU-174154', 'APC/C:Cdc20 mediated degradation of Securin'),
#     ('R-MMU-174178',
#      'APC/C:Cdh1 mediated degradation of Cdc20 and other APC/C:Cdh1 targeted proteins in late mitosis/early G1'),
#     ('R-MMU-174184', 'Cdc20:Phospho-APC/C mediated degradation of Cyclin A'),
#     ('R-MMU-195253', 'Degradation of beta-catenin by the destruction complex'),
#     ('R-MMU-202424', 'Downstream TCR signaling'),
#     ('R-MMU-2467813', 'Separation of Sister Chromatids'),
#     ('R-MMU-2871837', 'FCERI mediated NF-kB activation'),
#     ('R-MMU-349425', 'Autodegradation of the E3 ubiquitin ligase COP1'),
#     ('R-MMU-350562', 'Regulation of ornithine decarboxylase (ODC)'),
#     ('R-MMU-382556', 'ABC-family proteins mediated transport'),
#     ('R-MMU-450408', 'AUF1 (hnRNP D0) binds and destabilizes mRNA'),
#     ('R-MMU-4608870', 'Asymmetric localization of PCP proteins'),
#     ('R-MMU-4641257', 'Degradation of AXIN'),
#     ('R-MMU-4641258', 'Degradation of DVL'),
#     ('R-MMU-5358346', 'Hedgehog ligand biogenesis'),
#     ('R-MMU-5607761', 'Dectin-1 mediated noncanonical NF-kB signaling'),
#     ('R-MMU-5607764', 'CLEC7A (Dectin-1) signaling'),
#     ('R-MMU-5610780', 'Degradation of GLI1 by the proteasome'),
#     ('R-MMU-5610785', 'GLI3 is processed to GLI3R by the proteasome'),
#     ('R-MMU-5632684', "Hedgehog 'on' state"),
#     ('R-MMU-5658442', 'Regulation of RAS by GAPs'),
#     ('R-MMU-5668541', 'TNFR2 non-canonical NF-kB pathway'),
#     ('R-MMU-5676590', 'NIK-->noncanonical NF-kB signaling'),
#     ('R-MMU-5687128', 'MAPK6/MAPK4 signaling'),
#     ('R-MMU-5689603', 'UCH proteinases'),
#     ('R-MMU-5689880', 'Ub-specific processing proteases'),
#     ('R-MMU-68949', 'Orc1 removal from chromatin'),
#     ('R-MMU-69017', 'CDK-mediated phosphorylation and removal of Cdc6'),
#     ('R-MMU-69481', 'G2/M Checkpoints'),
#     ('R-MMU-69601', 'Ubiquitin Mediated Degradation of Phosphorylated Cdc25A'),
#     ('R-MMU-75815', 'Ubiquitin-dependent degradation of Cyclin D'),
#     ('R-MMU-8852276',
#      'The role of GTSE1 in G2/M progression after G2 checkpoint'),
#     ('R-MMU-8854050',
#      'FBXL7 down-regulates AURKA during mitotic entry and in early mitosis'),
#     ('R-MMU-8932339', 'ROS sensing by NFE2L2'),
#     ('R-MMU-8939236',
#      'RUNX1 regulates transcription of genes involved in differentiation of HSCs'),
#     ('R-MMU-8948751', 'Regulation of PTEN stability and activity'),
#     ('R-MMU-8951664', 'Neddylation'),
#     ('R-MMU-9020702', 'Interleukin-1 signaling'),
#     ('R-MMU-983168',
#      'Antigen processing: Ubiquitination & Proteasome degradation')]},
#   'R-MMU-9008787': {'reactome_id': 'R-MMU-9008787',
#    'name': 'Proteasome subunit beta type-10 [nucleoplasm]',
#    'pathways': [('R-MMU-174084', 'Autodegradation of Cdh1 by Cdh1:APC/C'),
#     ('R-MMU-174178',
#      'APC/C:Cdh1 mediated degradation of Cdc20 and other APC/C:Cdh1 targeted proteins in late mitosis/early G1'),
#     ('R-MMU-187577', 'SCF(Skp2)-mediated degradation of p27/p21'),
#     ('R-MMU-5632684', "Hedgehog 'on' state"),
#     ('R-MMU-68867', 'Assembly of the pre-replicative complex'),
#     ('R-MMU-8939902', 'Regulation of RUNX2 expression and activity'),
#     ('R-MMU-8941858', 'Regulation of RUNX3 expression and activity')]}},
#  'O35963': {'R-MMU-6810968': {'reactome_id': 'R-MMU-6810968',
#    'name': 'Rab33b [Golgi membrane]',
#    'pathways': [('R-MMU-6811438', 'Intra-Golgi traffic')]},
#   'R-MMU-8854609': {'reactome_id': 'R-MMU-8854609',
#    'name': 'Rab33b [Golgi membrane]',
#    'pathways': [('R-MMU-8854214', 'TBC/RABGAPs')]},
#   'R-MMU-8873702': {'reactome_id': 'R-MMU-8873702',
#    'name': 'Rab33b [cytosol]',
#    'pathways': [('R-MMU-8873719', 'RAB geranylgeranylation')]},
#   'R-MMU-8874107': {'reactome_id': 'R-MMU-8874107',
#    'name': 'Rab33b [cytosol]',
#    'pathways': [('R-MMU-8873719', 'RAB geranylgeranylation')]}},
#  'O35969': {'R-MMU-71276': {'reactome_id': 'R-MMU-71276',
#    'name': 'Gamt [cytosol]',
#    'pathways': [('R-MMU-71288', 'Creatine metabolism')]}},
#  'O35972': {'R-MMU-5368179': {'reactome_id': 'R-MMU-5368179',
#    'name': 'Mrpl23 [mitochondrial inner membrane]',
#    'pathways': [('R-MMU-5389840', 'Mitochondrial translation elongation'),
#     ('R-MMU-5419276', 'Mitochondrial translation termination')]}},
#  'O35980': {'R-MMU-60537': {'reactome_id': 'R-MMU-60537',
#    'name': 'Nthl1 [nucleoplasm]',
#    'pathways': [('R-MMU-110329', 'Cleavage of the damaged pyrimidine '),
#     ('R-MMU-110357', 'Displacement of DNA glycosylase by APEX1')]}},
#  'O35988': {'R-MMU-2064100': {'reactome_id': 'R-MMU-2064100',
#    'name': 'Sdc4 [Golgi lumen]',
#    'pathways': [('R-MMU-1971475',
#      'A tetrasaccharide linker sequence is required for GAG synthesis')]},
#   'R-MMU-2064067': {'reactome_id': 'R-MMU-2064067',
#    'name': 'Sdc4 [Golgi lumen]',
#    'pathways': [('R-MMU-1971475',
#      'A tetrasaccharide linker sequence is required for GAG synthesis'),
#     ('R-MMU-2022928', 'HS-GAG biosynthesis')]},
#   'R-MMU-2064249': {'reactome_id': 'R-MMU-2064249',
#    'name': 'Sdc4 [Golgi lumen]',
#    'pathways': [('R-MMU-1971475',
#      'A tetrasaccharide linker sequence is required for GAG synthesis')]},
#   'R-MMU-2064195': {'reactome_id': 'R-MMU-2064195',
#    'name': 'Sdc4 [Golgi lumen]',
#    'pathways': [('R-MMU-1971475',
#      'A tetrasaccharide linker sequence is required for GAG synthesis')]},
#   'R-MMU-2054111': {'reactome_id': 'R-MMU-2054111',
#    'name': 'Sdc4 [Golgi lumen]',
#    'pathways': [('R-MMU-1971475',
#      'A tetrasaccharide linker sequence is required for GAG synthesis')]},
#   'R-MMU-2076374': {'reactome_id': 'R-MMU-2076374',
#    'name': 'Sdc4 [Golgi lumen]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis')]},
#   'R-MMU-2076394': {'reactome_id': 'R-MMU-2076394',
#    'name': 'Sdc4 [Golgi lumen]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis')]},
#   'R-MMU-2076446': {'reactome_id': 'R-MMU-2076446',
#    'name': 'Sdc4 [Golgi lumen]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis')]},
#   'R-MMU-2076460': {'reactome_id': 'R-MMU-2076460',
#    'name': 'Sdc4 [Golgi lumen]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis')]},
#   'R-MMU-2076613': {'reactome_id': 'R-MMU-2076613',
#    'name': 'Sdc4 [Golgi lumen]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis')]},
#   'R-MMU-2076434': {'reactome_id': 'R-MMU-2076434',
#    'name': 'Sdc4 [Golgi lumen]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis')]},
#   'R-MMU-2076411': {'reactome_id': 'R-MMU-2076411',
#    'name': 'Sdc4 [Golgi lumen]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis')]},
#   'R-MMU-2076407': {'reactome_id': 'R-MMU-2076407',
#    'name': 'Sdc4 [Golgi lumen]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis')]},
#   'R-MMU-2076418': {'reactome_id': 'R-MMU-2076418',
#    'name': 'Sdc4 [Golgi lumen]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis')]},
#   'R-MMU-2076674': {'reactome_id': 'R-MMU-2076674',
#    'name': 'Sdc4 [plasma membrane]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis'),
#     ('R-MMU-975634', 'Retinoid metabolism and transport')]},
#   'R-MMU-2076694': {'reactome_id': 'R-MMU-2076694',
#    'name': 'Sdc4 [plasma membrane]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis'),
#     ('R-MMU-975634', 'Retinoid metabolism and transport')]},
#   'R-MMU-2076633': {'reactome_id': 'R-MMU-2076633',
#    'name': 'Sdc4 [plasma membrane]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis'),
#     ('R-MMU-2024096', 'HS-GAG degradation'),
#     ('R-MMU-975634', 'Retinoid metabolism and transport')]},
#   'R-MMU-2076635': {'reactome_id': 'R-MMU-2076635',
#    'name': 'Sdc4 [plasma membrane]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis'),
#     ('R-MMU-975634', 'Retinoid metabolism and transport')]},
#   'R-MMU-2076653': {'reactome_id': 'R-MMU-2076653',
#    'name': 'Sdc4 [plasma membrane]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis'),
#     ('R-MMU-202733', 'Cell surface interactions at the vascular wall'),
#     ('R-MMU-3000170', 'Syndecan interactions'),
#     ('R-MMU-975634', 'Retinoid metabolism and transport')]},
#   'R-MMU-2076670': {'reactome_id': 'R-MMU-2076670',
#    'name': 'Sdc4 [plasma membrane]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis'),
#     ('R-MMU-975634', 'Retinoid metabolism and transport')]},
#   'R-MMU-2076510': {'reactome_id': 'R-MMU-2076510',
#    'name': 'Sdc4 [Golgi lumen]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis')]},
#   'R-MMU-2076330': {'reactome_id': 'R-MMU-2076330',
#    'name': 'Sdc4 [Golgi lumen]',
#    'pathways': [('R-MMU-2022928', 'HS-GAG biosynthesis')]},
#   'R-MMU-2090058': {'reactome_id': 'R-MMU-2090058',
#    'name': 'Sdc4 [lysosomal lumen]',
#    'pathways': [('R-MMU-2024096', 'HS-GAG degradation')]},
#   'R-MMU-2090041': {'reactome_id': 'R-MMU-2090041',
#    'name': 'Sdc4 [lysosomal lumen]',
#    'pathways': [('R-MMU-2024096', 'HS-GAG degradation')]},
#   'R-MMU-2090061': {'reactome_id': 'R-MMU-2090061',
#    'name': 'Sdc4 [plasma membrane]',
#    'pathways': [('R-MMU-2024096', 'HS-GAG degradation')]}},
#  'O54689': {'R-MMU-373089': {'reactome_id': 'R-MMU-373089',
#    'name': 'Ccr6 [plasma membrane]',
#    'pathways': [('R-MMU-1461957', 'Beta defensins'),
#     ('R-MMU-380108', 'Chemokine receptors bind chemokines'),
#     ('R-MMU-418594', 'G alpha (i) signalling events')]}},
#  'O54692': {'R-MMU-377880': {'reactome_id': 'R-MMU-377880',
#    'name': 'Zw10 [cytosol]',
#    'pathways': [('R-MMU-141444',
#      'Amplification  of signal from unattached  kinetochores via a MAD2  inhibitory signal'),
#     ('R-MMU-2467813', 'Separation of Sister Chromatids'),
#     ('R-MMU-2500257', 'Resolution of Sister Chromatid Cohesion'),
#     ('R-MMU-5663220', 'RHO GTPases Activate Formins'),
#     ('R-MMU-6811434', 'COPI-dependent Golgi-to-ER retrograde traffic'),
#     ('R-MMU-68877', 'Mitotic Prometaphase'),
#     ('R-MMU-9648025', 'EML4 and NUDC in mitotic spindle formation')]}},
#  'O54693': {'R-MMU-5667156': {'reactome_id': 'R-MMU-5667156',
#    'name': 'Eda [plasma membrane]',
#    'pathways': [('R-MMU-5669034',
#      'TNFs bind their physiological receptors')]}},
#  ...}

# %%
class ReactomeQuery:
    def __init__(self, query_data, target_organism, id_database):
        self.query_data = query_data
        self.query_results = {}
        self.all_contained_pathways = []
        self.get_query_results(target_organism, id_database)
        self.calc_all_pathways()

    def asdict(self):
        """ return the ReactomePathway  as dictionary 
        """
        return {}        
    def get_query_results(self, tar, db):
        with open('{}_{}2reactome.pickle'.format(tar,db), 'rb') as handle:
            reactome_data = pickle.load(handle)
            for elem in self.query_data:
                reactome_elem = reactome_data[elem[0]]
                for pathway_id in reactome_elem:
                    reactome_elem[pathway_id]['measurement'] = elem[1]
                self.query_results[elem[0]] = reactome_elem
    def calc_all_pathways(self):
        pathways = []
        for k, v in self.query_results.items():
            for reactome_id, physical_entity in v.items():
                pathways.extend(physical_entity['pathways'])
        self.all_contained_pathways = list(set(pathways))

    def get_levels_of_query(self, hierarchy, level):
        out_pathways = []
        for elem in self.all_contained_pathways:
            if hierarchy[elem[0]].level == level:
                out_pathways.append(elem)

        return out_pathways
    def get_target_level_for_query_pathways(self, hierarchy, tar_level):
        out_pathways = {}
        for uniprot_ID, query_result in self.query_results.items():
            for entity_ID, entity_entry in query_result.items():
                for pathway in entity_entry['pathways']:
                    if hierarchy[pathway[0]].level == tar_level:
                        current_id = pathway[0]
                        current_level = hierarchy[pathway[0]].level
                        if current_id in out_pathways:
                            if uniprot_ID not in out_pathways[hierarchy[current_id].reactome_sID]:
                                out_pathways[hierarchy[current_id].reactome_sID][uniprot_ID] = {'entity_IDs':[entity_ID] ,'entity_names': [entity_entry['name']] , 'measurement': entity_entry['measurement']}
                            elif entity_ID not in out_pathways[hierarchy[current_id].reactome_sID][uniprot_ID]['entity_IDs']:
                                out_pathways[hierarchy[current_id].reactome_sID][uniprot_ID]['entity_IDs'].append(entity_ID)
                                out_pathways[hierarchy[current_id].reactome_sID][uniprot_ID]['entity_names'].append(entity_entry['name'])
                        else: 
                            out_pathways[hierarchy[current_id].reactome_sID] = {uniprot_ID: {'entity_IDs':[entity_ID] ,'entity_names': [entity_entry['name']] , 'measurement': entity_entry['measurement']}}

                    else:
                        current_id = pathway[0]
                        current_level = hierarchy[pathway[0]].level
                        while current_level > tar_level:
                            current_id = hierarchy[current_id].parents[0]
                            current_level = hierarchy[current_id].level
                        if current_id in out_pathways:
                            if uniprot_ID not in out_pathways[hierarchy[current_id].reactome_sID]:
                                out_pathways[hierarchy[current_id].reactome_sID][uniprot_ID] = {'entity_IDs':[entity_ID] ,'entity_names': [entity_entry['name']] , 'measurement': entity_entry['measurement']}
                            elif entity_ID not in out_pathways[hierarchy[current_id].reactome_sID][uniprot_ID]['entity_IDs']:
                                out_pathways[hierarchy[current_id].reactome_sID][uniprot_ID]['entity_IDs'].append(entity_ID)
                                out_pathways[hierarchy[current_id].reactome_sID][uniprot_ID]['entity_names'].append(entity_entry['name'])
                        else: 
                            out_pathways[hierarchy[current_id].reactome_sID] = {uniprot_ID: {'entity_IDs':[entity_ID] ,'entity_names': [entity_entry['name']] , 'measurement': entity_entry['measurement']}}


        return out_pathways

# %%
testUniprot = [("Q8BWN8", 1.0),
("P47740", 2.0),
("Q9R0H0", 3.0),
("Q9DBK0", 4.0),
("O88844", 5.0),
("Q9D379", 6.0),
("P34914", 7.0),
("Q9QZD8", 8.0),
("O08756", 9.0),
("P45952", 10.0)
]

# %%
tar_organism = 'Mus_musculus'
test_query = ReactomeQuery(testUniprot, tar_organism, 'uniprot')

# %%
test_query.query_results
# Out:
# {'Q8BWN8': {'R-MMU-5690054': {'reactome_id': 'R-MMU-5690054',
#    'name': 'Acot4 [peroxisomal matrix]',
#    'pathways': [('R-MMU-390247',
#      'Beta-oxidation of very long chain fatty acids'),
#     ('R-MMU-9033241', 'Peroxisomal protein import')],
#    'measurement': 1.0},
#   'R-MMU-9033145': {'reactome_id': 'R-MMU-9033145',
#    'name': 'Acot4 [cytosol]',
#    'pathways': [('R-MMU-9033241', 'Peroxisomal protein import')],
#    'measurement': 1.0}},
#  'P47740': {'R-MMU-6811616': {'reactome_id': 'R-MMU-6811616',
#    'name': 'Aldh3a2 [endoplasmic reticulum membrane]',
#    'pathways': [('R-MMU-1660661', 'Sphingolipid de novo biosynthesis')],
#    'measurement': 2.0},
#   'R-MMU-6811617': {'reactome_id': 'R-MMU-6811617',
#    'name': 'Aldh3a2 [peroxisomal membrane]',
#    'pathways': [('R-MMU-389599', 'Alpha-oxidation of phytanate'),
#     ('R-MMU-9603798', 'Class I peroxisomal membrane protein import')],
#    'measurement': 2.0},
#   'R-MMU-9603785': {'reactome_id': 'R-MMU-9603785',
#    'name': 'Aldh3a2 [cytosol]',
#    'pathways': [('R-MMU-9603798',
#      'Class I peroxisomal membrane protein import'),
#     ('R-MMU-9609523',
#      'Insertion of tail-anchored proteins into the endoplasmic reticulum membrane'),
#     ('R-MMU-9696270', 'RND2 GTPase cycle'),
#     ('R-MMU-9696273', 'RND1 GTPase cycle')],
#    'measurement': 2.0}},
#  'Q9R0H0': {'R-MMU-390263': {'reactome_id': 'R-MMU-390263',
#    'name': 'Acox1 [peroxisomal matrix]',
#    'pathways': [('R-MMU-2046106', 'alpha-linolenic acid (ALA) metabolism'),
#     ('R-MMU-390247', 'Beta-oxidation of very long chain fatty acids'),
#     ('R-MMU-9033241', 'Peroxisomal protein import')],
#    'measurement': 3.0},
#   'R-MMU-9033085': {'reactome_id': 'R-MMU-9033085',
#    'name': 'Acox1 [cytosol]',
#    'pathways': [('R-MMU-9033241', 'Peroxisomal protein import')],
#    'measurement': 3.0}},
#  'Q9DBK0': {'R-MMU-5690072': {'reactome_id': 'R-MMU-5690072',
#    'name': 'Acot12 [cytosol]',
#    'pathways': [('R-MMU-77289', 'Mitochondrial Fatty Acid Beta-Oxidation')],
#    'measurement': 4.0}},
#  'O88844': {'R-MMU-389546': {'reactome_id': 'R-MMU-389546',
#    'name': 'Idh1 [peroxisomal matrix]',
#    'pathways': [('R-MMU-389542', 'NADPH regeneration'),
#     ('R-MMU-9033241', 'Peroxisomal protein import')],
#    'measurement': 5.0},
#   'R-MMU-389549': {'reactome_id': 'R-MMU-389549',
#    'name': 'Idh1 [cytosol]',
#    'pathways': [('R-MMU-389542', 'NADPH regeneration'),
#     ('R-MMU-9033241', 'Peroxisomal protein import')],
#    'measurement': 5.0},
#   'R-MMU-6800163': {'reactome_id': 'R-MMU-6800163',
#    'name': 'Idh1 [tertiary granule lumen]',
#    'pathways': [('R-MMU-6798695', 'Neutrophil degranulation')],
#    'measurement': 5.0},
#   'R-MMU-6806433': {'reactome_id': 'R-MMU-6806433',
#    'name': 'Idh1 [extracellular region]',
#    'pathways': [('R-MMU-6798695', 'Neutrophil degranulation')],
#    'measurement': 5.0},
#   'R-MMU-6800977': {'reactome_id': 'R-MMU-6800977',
#    'name': 'Idh1 [ficolin-1-rich granule lumen]',
#    'pathways': [('R-MMU-6798695', 'Neutrophil degranulation')],
#    'measurement': 5.0},
#   'R-MMU-6800980': {'reactome_id': 'R-MMU-6800980',
#    'name': 'Idh1 [secretory granule lumen]',
#    'pathways': [('R-MMU-6798695', 'Neutrophil degranulation')],
#    'measurement': 5.0}},
#  'Q9D379': {'R-MMU-5694132': {'reactome_id': 'R-MMU-5694132',
#    'name': 'Ephx1 [endoplasmic reticulum membrane]',
#    'pathways': [('R-MMU-211945', 'Phase I - Functionalization of compounds')],
#    'measurement': 6.0}},
#  'P34914': {'R-MMU-2142819': {'reactome_id': 'R-MMU-2142819',
#    'name': 'Ephx2 [cytosol]',
#    'pathways': [('R-MMU-2142670',
#      'Synthesis of epoxy (EET) and dihydroxyeicosatrienoic acids (DHET)'),
#     ('R-MMU-9018682', 'Biosynthesis of maresins'),
#     ('R-MMU-9033241', 'Peroxisomal protein import')],
#    'measurement': 7.0},
#   'R-MMU-9033088': {'reactome_id': 'R-MMU-9033088',
#    'name': 'Ephx2 [peroxisomal matrix]',
#    'pathways': [('R-MMU-9033241', 'Peroxisomal protein import')],
#    'measurement': 7.0}},
#  'Q9QZD8': {'R-MMU-372848': {'reactome_id': 'R-MMU-372848',
#    'name': 'Slc25a10 [mitochondrial inner membrane]',
#    'pathways': [('R-MMU-1614517', 'Sulfide oxidation to sulfate'),
#     ('R-MMU-428643', 'Organic anion transporters'),
#     ('R-MMU-70263', 'Gluconeogenesis')],
#    'measurement': 8.0}},
#  'O08756': {'R-MMU-70831': {'reactome_id': 'R-MMU-70831',
#    'name': 'Hsd17b10 [mitochondrial matrix]',
#    'pathways': [('R-MMU-70895', 'Branched-chain amino acid catabolism')],
#    'measurement': 9.0}},
#  'P45952': {'R-MMU-49491': {'reactome_id': 'R-MMU-49491',
#    'name': 'Acadm [mitochondrial matrix]',
#    'pathways': [('R-MMU-77288',
#      'mitochondrial fatty acid beta-oxidation of unsaturated fatty acids'),
#     ('R-MMU-77346', 'Beta oxidation of decanoyl-CoA to octanoyl-CoA-CoA'),
#     ('R-MMU-77348', 'Beta oxidation of octanoyl-CoA to hexanoyl-CoA')],
#    'measurement': 10.0}}}

# %%
len(test_query.all_contained_pathways)
# Out:
# 22

# %%
test_query.get_target_level_for_query_pathways(pathways, 1)
# Out:
# {'R-MMU-556833': {'Q8BWN8': {'entity_IDs': ['R-MMU-5690054'],
#    'entity_names': ['Acot4 [peroxisomal matrix]'],
#    'measurement': 1.0},
#   'P47740': {'entity_IDs': ['R-MMU-6811616', 'R-MMU-6811617'],
#    'entity_names': ['Aldh3a2 [endoplasmic reticulum membrane]',
#     'Aldh3a2 [peroxisomal membrane]'],
#    'measurement': 2.0},
#   'Q9R0H0': {'entity_IDs': ['R-MMU-390263'],
#    'entity_names': ['Acox1 [peroxisomal matrix]'],
#    'measurement': 3.0},
#   'Q9DBK0': {'entity_IDs': ['R-MMU-5690072'],
#    'entity_names': ['Acot12 [cytosol]'],
#    'measurement': 4.0},
#   'P34914': {'entity_IDs': ['R-MMU-2142819'],
#    'entity_names': ['Ephx2 [cytosol]'],
#    'measurement': 7.0},
#   'P45952': {'entity_IDs': ['R-MMU-49491'],
#    'entity_names': ['Acadm [mitochondrial matrix]'],
#    'measurement': 10.0}},
#  'R-MMU-9033241': {'Q8BWN8': {'entity_IDs': ['R-MMU-5690054', 'R-MMU-9033145'],
#    'entity_names': ['Acot4 [peroxisomal matrix]', 'Acot4 [cytosol]'],
#    'measurement': 1.0},
#   'Q9R0H0': {'entity_IDs': ['R-MMU-390263', 'R-MMU-9033085'],
#    'entity_names': ['Acox1 [peroxisomal matrix]', 'Acox1 [cytosol]'],
#    'measurement': 3.0},
#   'O88844': {'entity_IDs': ['R-MMU-389546', 'R-MMU-389549'],
#    'entity_names': ['Idh1 [peroxisomal matrix]', 'Idh1 [cytosol]'],
#    'measurement': 5.0},
#   'P34914': {'entity_IDs': ['R-MMU-2142819', 'R-MMU-9033088'],
#    'entity_names': ['Ephx2 [cytosol]', 'Ephx2 [peroxisomal matrix]'],
#    'measurement': 7.0}},
#  'R-MMU-9603798': {'P47740': {'entity_IDs': ['R-MMU-6811617', 'R-MMU-9603785'],
#    'entity_names': ['Aldh3a2 [peroxisomal membrane]', 'Aldh3a2 [cytosol]'],
#    'measurement': 2.0}},
#  'R-MMU-9609523': {'P47740': {'entity_IDs': ['R-MMU-9603785'],
#    'entity_names': ['Aldh3a2 [cytosol]'],
#    'measurement': 2.0}},
#  'R-MMU-9716542': {'P47740': {'entity_IDs': ['R-MMU-9603785'],
#    'entity_names': ['Aldh3a2 [cytosol]'],
#    'measurement': 2.0}},
#  'R-MMU-196854': {'O88844': {'entity_IDs': ['R-MMU-389546', 'R-MMU-389549'],
#    'entity_names': ['Idh1 [peroxisomal matrix]', 'Idh1 [cytosol]'],
#    'measurement': 5.0}},
#  'R-MMU-168249': {'O88844': {'entity_IDs': ['R-MMU-6800163',
#     'R-MMU-6806433',
#     'R-MMU-6800977',
#     'R-MMU-6800980'],
#    'entity_names': ['Idh1 [tertiary granule lumen]',
#     'Idh1 [extracellular region]',
#     'Idh1 [ficolin-1-rich granule lumen]',
#     'Idh1 [secretory granule lumen]'],
#    'measurement': 5.0}},
#  'R-MMU-211859': {'Q9D379': {'entity_IDs': ['R-MMU-5694132'],
#    'entity_names': ['Ephx1 [endoplasmic reticulum membrane]'],
#    'measurement': 6.0}},
#  'R-MMU-71291': {'Q9QZD8': {'entity_IDs': ['R-MMU-372848'],
#    'entity_names': ['Slc25a10 [mitochondrial inner membrane]'],
#    'measurement': 8.0},
#   'O08756': {'entity_IDs': ['R-MMU-70831'],
#    'entity_names': ['Hsd17b10 [mitochondrial matrix]'],
#    'measurement': 9.0}},
#  'R-MMU-425407': {'Q9QZD8': {'entity_IDs': ['R-MMU-372848'],
#    'entity_names': ['Slc25a10 [mitochondrial inner membrane]'],
#    'measurement': 8.0}},
#  'R-MMU-71387': {'Q9QZD8': {'entity_IDs': ['R-MMU-372848'],
#    'entity_names': ['Slc25a10 [mitochondrial inner membrane]'],
#    'measurement': 8.0}}}
